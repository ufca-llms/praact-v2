# %%
import json
pictograms = json.load(open("data/arasaac_en.json"))

# %%
search_id = 35949
c = 0
kw_count=0
for pictogram in pictograms:
    kw_count += len(pictogram["keywords"])
kw_count
# Out:
# 26377

# %%
len(pictograms)
# Out:
# 13733
