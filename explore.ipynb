# %%
import json
pictograms = json.load(open("data/arasaac_en.json"))

# %%
search_id = 35949
c = 0
kw_count=0
for pictogram in pictograms:
    print(json.dumps(pictogram, indent=2))
    break
# Out:
# {
#   "schematic": false,
#   "sex": false,
#   "violence": false,
#   "aac": false,
#   "aacColor": false,
#   "skin": false,
#   "hair": false,
#   "downloads": 0,
#   "categories": [
#     "infrastructure",
#     "land transport",
#     "road safety"
#   ],
#   "synsets": [
#     "04222469-n"
#   ],
#   "tags": [
#     "place",
#     "infrastructure",
#     "movement",
#     "traffic",
#     "mode of transport",
#     "land transport",
#     "road safety"
#   ],
#   "_id": 2247,
#   "created": "2007-12-12T10:04:45.000Z",
#   "lastUpdated": "2020-12-15T12:53:57.867Z",
#   "keywords": [
#     {
#       "type": 2,
#       "meaning": "f. Side of the road or other public highway paved with suitable for pedestrians, the road separating wall constructions.",
#       "keyword": "pavement",
#       "hasLocution": true,
#       "plural": "pavements"
#     },
#     {
#       "keyword": "sidewalk",
#       "hasLocution": true,
#       "type": 2,
#       "plural": "sidewalks"
#     }
#   ]
# ...

# %%
len(pictograms)
# Out:
# 13733
